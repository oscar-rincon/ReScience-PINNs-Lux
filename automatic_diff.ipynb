# %%
using TaylorDiff, Plots

# %%
using TaylorDiff
 
# Define the range and function
x = collect(range(0, 5, length=50))
f(x) = sin.(x)

# Calculate the first derivative
first_derivative = TaylorDiff.derivative.(f, x, Val(1))


plot(x, first_derivative)
